# %% [markdown]
# ###
#
# **https://www.databricks.com/learn/training/generative-ai-fundamentals-accreditation**

# %% [markdown]
# ### **Introduction to Generative AI  Fundamental**

# %% [markdown]
# ### **Generative AI Basics**
#
# Generattive AI USe cases
#
# What is LLM

# %% [markdown]
# ### **LLM Applications**
#
# Pre-trained Models
#
# Fine Tuned  Models
#
# Mixing LLM Flavors in a Workflow
#    * Tasks
#    * Workflow
#
# Retrieval Augmented Generation
#
# Databricks AI
# GenAI
#   * Custom Models
#   * Model Serving
#   * RAG
#
# End-to-End AI
#  * MLOps(MLFlow)
#  * AutoML
#  * Monitoring
#  * Governance
#
# AI Adoption Preparation
# Strategic Roadmap for AI  Adoption
#  1. Define GenAI Strategy
#  2. Business Use cases
#  3. Design & Architecture
#  4. Operation & Monitoring
#  5. People & Adoption

# %% [markdown]
# ![](attachment:image.png)

# %% [markdown]
# ### **Assessing Potential Risks and Challenges**
