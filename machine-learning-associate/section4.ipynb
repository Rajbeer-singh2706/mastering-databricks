# %% [markdown]
# # **Section 4: AUTO ML(Classification, Regression, Forecasting)**

# %% [markdown]
# ### **14. Introduction to AUTOML**
# ![image.png](attachment:image.png)

# %% [markdown]
# # **15. AutoML Regression Databricks UI Part - 1**

# %% [markdown]
#  * Azure Potal
#  * workspace: databricks-ml-
#  * Compute: : cluster-01-ml: Runtime: 12.2 ML
#  * Data : UPload the dataset : housing.csv
#  * settings => Admin Console => Workspace settings => DBFS FIle Browser :ENABLED
#  * Data => Brows DBFS => /FielStore => Upload housing.csv
#  * Data => Hive_metasore => NO table Available

# %%
## Dataset: housing.csv 
# First Convert this CSV into Delta Table 
## Workspace => Databricks-ml => AUtoML => New Notebook
## Create Tables

# %% [markdown]
# ## Creating table for regression

# %%
from pyspark.sql.types import DoubleType,StringType, StructType, StructField

schema = StructType([
  StructField("longitude", DoubleType(), True),
  StructField("latitude", DoubleType(), True),
  StructField("housing_median_age", DoubleType(), True),
  StructField("total_rooms", DoubleType(), True),
  StructField("total_bedrooms", DoubleType(), True),
  StructField("population", DoubleType(), True),
  StructField("households", DoubleType(), True),
  StructField("median_income", DoubleType(), True),
  StructField("meidan_house_value", DoubleType(), True),
  StructField("ocean_proximity", StringType(), True)
])

housing_df = spark.read.format("csv").schema(schema).option("header","true").load("/FileStore/housing.csv")

# %%
housing_df.write.saveAsTable("default.housing_t") # default schema,

# %%
# %sql 
select * from default.housing_t

# Data Explored => hive_metastore => defualt => housing_t ( Check the details )

# %% [markdown]
# # **16. AutoML Regression Databricks UI Part - 2**

# %% [markdown]
# * Machine Learning => Experiments => Create AutoML Experiments
# * 1. Configure
#   * Cluster                 : cluster-01-ml(14GB-4 core- DBR 12.2 LTS ML - Spark 3.3.2 - Scala 2.12 )
#   * ML Problem type         : Regression
#   * Input training dataset  : default.housing_t [ deselect longitude, latitude ]
#   * prediction target       : median_house_value
#   * Experiment name         : AutoML - Regression From UI
# * Advance Configuration
#   * Evalution metric: R-Squared
#   * training Framwework : lightgbm, sklearn, xgboost
#   * Timeout(minutes): 15
#   * Intermediate Location : MLFlow Artifcat
# 2. Join Features
# 3. Train => Start AUTOML

# %% [markdown]
# # **17. AutoML Regression Databricks UI Part - 3**
